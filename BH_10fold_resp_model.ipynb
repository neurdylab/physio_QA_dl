# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from tensorflow.keras import Input
from tensorflow.keras import Model

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.model_selection import KFold

from scipy.signal import find_peaks
from scipy.stats import mode
import numpy as np
import pickle
import matplotlib.pyplot as plt
# Out:
# 2024-01-10 08:33:20.157228: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# Load input/label to models
# RESPIRATION
with open('resp_input.pkl', 'rb') as file:
    x = pickle.load(file)
    
with open('resp_label.pkl', 'rb') as file:
    y = pickle.load(file)

# CARDIAC
# with open('cardiac_input.pkl', 'rb') as file:
#     x = pickle.load(file)

# with open('cardiac_label.pkl', 'rb') as file:
#     y = pickle.load(file)

# %%
nanmask = np.isnan(y)
print(f'#Nan Labels: {np.sum(nanmask)}\n#Remaining Samples: {np.sum(~nanmask)}')
y = y[~nanmask]
x = x[~nanmask]
# Out:
# #Nan Labels: 590
# #Remaining Samples: 3304

# %%
### GOAL is to achieve 95% classification accuracy on 10-fold CV

# Step 1: Experiment with different param. + hyperparam.: layers, kernel, stride, filter size ( see https://keras.io/api/layers/convolution_layers/convolution1d/ )
# Step 2: Experiment with different architectures

test_loss, test_acc = [], []

kernel = 5
stride = 3
kfold = KFold(n_splits=10) #, shuffle=True)
i = 0
for train, test in kfold.split(x, y):
    # Data normalization
    scaler = StandardScaler()
    X_train = scaler.fit_transform(x[train])
    X_test = scaler.transform(x[test])

    y_train = y[train]
    y_test = y[test]
    
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))


    # TO DO: Experiment with different model architectures
    model = Sequential([
        layers.Conv1D(64, kernel, stride, activation='relu', input_shape=X_train.shape[1:]),
        layers.Conv1D(32, kernel, stride, activation='relu'),
        layers.Conv1D(16, kernel, stride, activation='relu'),
        layers.Conv1D(8, kernel, stride, activation='relu'),
        layers.Flatten(),
        layers.Dense(1, activation='sigmoid')
    ])
        
    # Define the early stopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',  # Metric to monitor (e.g., validation loss)
        patience=5,           # Number of epochs with no improvement after which training will be stopped
        restore_best_weights=True,  # Restore model weights to the best achieved during training
        verbose=1  # Set to 1 to see messages about the early stopping process
    )
    
    optimizer = optimizers.Adam(learning_rate=0.001)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    
    history = model.fit(
        X_train,
        y_train,
        epochs=25,      
        validation_split=0.2,
        batch_size=2,
        callbacks=[early_stopping]  # Add the early stopping callback
    )
    
    loss, accuracy = model.evaluate(X_test, y_test, batch_size=1)
    print(f"Fold {i} Test Accuracy: {accuracy * 100:.2f}%")
    i = i + 1
    test_loss.append(loss)
    test_acc.append(accuracy)

print("{} Fold Accuracy: {:.2f}%\u00b1{:.2f}".format(i, np.mean(test_acc)*100, np.std(test_acc)*100))
# Out:
# Epoch 1/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.5120 - accuracy: 0.7733 - val_loss: 0.4805 - val_accuracy: 0.7664
# Epoch 2/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.3850 - accuracy: 0.8272 - val_loss: 0.4558 - val_accuracy: 0.7731
# Epoch 3/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.3227 - accuracy: 0.8654 - val_loss: 0.4526 - val_accuracy: 0.7849
# Epoch 4/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.2478 - accuracy: 0.8957 - val_loss: 0.5329 - val_accuracy: 0.7580
# Epoch 5/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.1902 - accuracy: 0.9188 - val_loss: 0.5782 - val_accuracy: 0.7647
# Epoch 6/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.1618 - accuracy: 0.9441 - val_loss: 2.8049 - val_accuracy: 0.6958
# Epoch 7/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.1211 - accuracy: 0.9613 - val_loss: 0.8458 - val_accuracy: 0.7815
# Epoch 8/25
# 1186/1189 [============================>.] - ETA: 0s - loss: 0.1162 - accuracy: 0.9595Restoring model weights from the end of the best epoch: 3.
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.1159 - accuracy: 0.9596 - val_loss: 1.2237 - val_accuracy: 0.7765
# Epoch 8: early stopping
# 331/331 [==============================] - 1s 2ms/step - loss: 0.5817 - accuracy: 0.7432
# Fold 0 Test Accuracy: 74.32%
# Epoch 1/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.5278 - accuracy: 0.7553 - val_loss: 0.5233 - val_accuracy: 0.7681
# Epoch 2/25
# 1189/1189 [==============================] - 18s 16ms/step - loss: 0.3925 - accuracy: 0.8217 - val_loss: 0.5008 - val_accuracy: 0.7815
# Epoch 3/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.3249 - accuracy: 0.8621 - val_loss: 0.4747 - val_accuracy: 0.7798
# Epoch 4/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.2870 - accuracy: 0.8835 - val_loss: 0.6494 - val_accuracy: 0.7546
# Epoch 5/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.2318 - accuracy: 0.9096 - val_loss: 0.7820 - val_accuracy: 0.7731
# Epoch 6/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.1992 - accuracy: 0.9298 - val_loss: 0.5895 - val_accuracy: 0.7966
# Epoch 7/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.1482 - accuracy: 0.9474 - val_loss: 0.9288 - val_accuracy: 0.7916
# Epoch 8/25
# 1188/1189 [============================>.] - ETA: 0s - loss: 0.1357 - accuracy: 0.9541Restoring model weights from the end of the best epoch: 3.
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.1357 - accuracy: 0.9542 - val_loss: 0.8749 - val_accuracy: 0.7782
# Epoch 8: early stopping
# 331/331 [==============================] - 1s 2ms/step - loss: 0.4670 - accuracy: 0.7764
# Fold 1 Test Accuracy: 77.64%
# Epoch 1/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.5486 - accuracy: 0.7279 - val_loss: 0.5342 - val_accuracy: 0.7479
# Epoch 2/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.4084 - accuracy: 0.8162 - val_loss: 0.4323 - val_accuracy: 0.8050
# Epoch 3/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.3286 - accuracy: 0.8629 - val_loss: 0.6905 - val_accuracy: 0.7630
# Epoch 4/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.2434 - accuracy: 0.8966 - val_loss: 0.5841 - val_accuracy: 0.7748
# Epoch 5/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.1503 - accuracy: 0.9458 - val_loss: 0.6824 - val_accuracy: 0.7782
# Epoch 6/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.1319 - accuracy: 0.9529 - val_loss: 0.7027 - val_accuracy: 0.7731
# Epoch 7/25
# 1187/1189 [============================>.] - ETA: 0s - loss: 0.0804 - accuracy: 0.9751Restoring model weights from the end of the best epoch: 2.
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.0803 - accuracy: 0.9752 - val_loss: 0.9375 - val_accuracy: 0.7832
# Epoch 7: early stopping
# 331/331 [==============================] - 1s 2ms/step - loss: 0.2465 - accuracy: 0.9063
# Fold 2 Test Accuracy: 90.63%
# Epoch 1/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.5230 - accuracy: 0.7485 - val_loss: 0.4523 - val_accuracy: 0.7630
# Epoch 2/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.3939 - accuracy: 0.8162 - val_loss: 0.5357 - val_accuracy: 0.7630
# Epoch 3/25
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.3376 - accuracy: 0.8612 - val_loss: 0.4928 - val_accuracy: 0.7815
# Epoch 4/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.2766 - accuracy: 0.8936 - val_loss: 0.5128 - val_accuracy: 0.8084
# Epoch 5/25
# 1189/1189 [==============================] - 17s 14ms/step - loss: 0.1842 - accuracy: 0.9272 - val_loss: 0.6706 - val_accuracy: 0.7832
# Epoch 6/25
# 1189/1189 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9554Restoring model weights from the end of the best epoch: 1.
# 1189/1189 [==============================] - 16s 14ms/step - loss: 0.1298 - accuracy: 0.9554 - val_loss: 0.7718 - val_accuracy: 0.7899
# Epoch 6: early stopping
# 331/331 [==============================] - 1s 3ms/step - loss: 0.4294 - accuracy: 0.7915
# Fold 3 Test Accuracy: 79.15%
# Epoch 1/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.5092 - accuracy: 0.7633 - val_loss: 0.4461 - val_accuracy: 0.7933
# Epoch 2/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.3694 - accuracy: 0.8483 - val_loss: 0.4033 - val_accuracy: 0.8202
# Epoch 3/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.3115 - accuracy: 0.8781 - val_loss: 0.4062 - val_accuracy: 0.8134
# Epoch 4/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2519 - accuracy: 0.9033 - val_loss: 1.7991 - val_accuracy: 0.6992
# Epoch 5/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2034 - accuracy: 0.9227 - val_loss: 0.6717 - val_accuracy: 0.7983
# Epoch 6/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1573 - accuracy: 0.9449 - val_loss: 0.5575 - val_accuracy: 0.8151
# Epoch 7/25
# 1188/1190 [============================>.] - ETA: 0s - loss: 0.1203 - accuracy: 0.9550Restoring model weights from the end of the best epoch: 2.
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1202 - accuracy: 0.9550 - val_loss: 1.1869 - val_accuracy: 0.7731
# Epoch 7: early stopping
# 330/330 [==============================] - 1s 2ms/step - loss: 0.4702 - accuracy: 0.7697
# Fold 4 Test Accuracy: 76.97%
# Epoch 1/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.4956 - accuracy: 0.7642 - val_loss: 0.7441 - val_accuracy: 0.7059
# Epoch 2/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.3832 - accuracy: 0.8365 - val_loss: 0.4434 - val_accuracy: 0.7815
# Epoch 3/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.3332 - accuracy: 0.8676 - val_loss: 0.5291 - val_accuracy: 0.8067
# Epoch 4/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2400 - accuracy: 0.9126 - val_loss: 0.5367 - val_accuracy: 0.8101
# Epoch 5/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1563 - accuracy: 0.9445 - val_loss: 0.9591 - val_accuracy: 0.7647
# Epoch 6/25
# 1190/1190 [==============================] - 18s 15ms/step - loss: 0.1006 - accuracy: 0.9626 - val_loss: 1.1017 - val_accuracy: 0.7697
# Epoch 7/25
# 1188/1190 [============================>.] - ETA: 0s - loss: 0.0936 - accuracy: 0.9743Restoring model weights from the end of the best epoch: 2.
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.0935 - accuracy: 0.9744 - val_loss: 1.0977 - val_accuracy: 0.7815
# Epoch 7: early stopping
# 330/330 [==============================] - 1s 3ms/step - loss: 0.3176 - accuracy: 0.8515
# Fold 5 Test Accuracy: 85.15%
# Epoch 1/25
# 1190/1190 [==============================] - 18s 14ms/step - loss: 0.5183 - accuracy: 0.7486 - val_loss: 0.6797 - val_accuracy: 0.6605
# Epoch 2/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.4010 - accuracy: 0.8289 - val_loss: 0.4240 - val_accuracy: 0.8134
# Epoch 3/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.3498 - accuracy: 0.8558 - val_loss: 0.4524 - val_accuracy: 0.7933
# Epoch 4/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2788 - accuracy: 0.8882 - val_loss: 0.7195 - val_accuracy: 0.7580
# Epoch 5/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2141 - accuracy: 0.9222 - val_loss: 0.5931 - val_accuracy: 0.7782
# Epoch 6/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1630 - accuracy: 0.9395 - val_loss: 1.0782 - val_accuracy: 0.7395
# Epoch 7/25
# 1187/1190 [============================>.] - ETA: 0s - loss: 0.1159 - accuracy: 0.9621Restoring model weights from the end of the best epoch: 2.
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1157 - accuracy: 0.9622 - val_loss: 0.7991 - val_accuracy: 0.7950
# Epoch 7: early stopping
# 330/330 [==============================] - 1s 2ms/step - loss: 0.3354 - accuracy: 0.8697
# Fold 6 Test Accuracy: 86.97%
# Epoch 1/25
# 1190/1190 [==============================] - 18s 14ms/step - loss: 0.5518 - accuracy: 0.7356 - val_loss: 0.4963 - val_accuracy: 0.7546
# Epoch 2/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.4022 - accuracy: 0.8319 - val_loss: 0.8164 - val_accuracy: 0.7244
# Epoch 3/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.3597 - accuracy: 0.8579 - val_loss: 0.6364 - val_accuracy: 0.7345
# Epoch 4/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2709 - accuracy: 0.8983 - val_loss: 0.6018 - val_accuracy: 0.7832
# Epoch 5/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2198 - accuracy: 0.9243 - val_loss: 0.9263 - val_accuracy: 0.7782
# Epoch 6/25
# 1188/1190 [============================>.] - ETA: 0s - loss: 0.1710 - accuracy: 0.9386Restoring model weights from the end of the best epoch: 1.
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1708 - accuracy: 0.9386 - val_loss: 0.8228 - val_accuracy: 0.7765
# Epoch 6: early stopping
# 330/330 [==============================] - 1s 3ms/step - loss: 0.3370 - accuracy: 0.8364
# Fold 7 Test Accuracy: 83.64%
# Epoch 1/25
# 1190/1190 [==============================] - 18s 14ms/step - loss: 0.5332 - accuracy: 0.7499 - val_loss: 0.4865 - val_accuracy: 0.8050
# Epoch 2/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.4077 - accuracy: 0.8306 - val_loss: 0.5727 - val_accuracy: 0.7311
# Epoch 3/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.3323 - accuracy: 0.8554 - val_loss: 0.4128 - val_accuracy: 0.8134
# Epoch 4/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2596 - accuracy: 0.8991 - val_loss: 1.2926 - val_accuracy: 0.6958
# Epoch 5/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1978 - accuracy: 0.9285 - val_loss: 0.5924 - val_accuracy: 0.8084
# Epoch 6/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1371 - accuracy: 0.9563 - val_loss: 0.7233 - val_accuracy: 0.7950
# Epoch 7/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1363 - accuracy: 0.9617 - val_loss: 0.7328 - val_accuracy: 0.8034
# Epoch 8/25
# 1189/1190 [============================>.] - ETA: 0s - loss: 0.0969 - accuracy: 0.9693Restoring model weights from the end of the best epoch: 3.
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.0970 - accuracy: 0.9693 - val_loss: 1.0217 - val_accuracy: 0.7950
# Epoch 8: early stopping
# 330/330 [==============================] - 1s 2ms/step - loss: 0.3572 - accuracy: 0.8455
# Fold 8 Test Accuracy: 84.55%
# Epoch 1/25
# 1190/1190 [==============================] - 18s 14ms/step - loss: 0.5328 - accuracy: 0.7423 - val_loss: 0.4568 - val_accuracy: 0.7613
# Epoch 2/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.4037 - accuracy: 0.8134 - val_loss: 0.5684 - val_accuracy: 0.7866
# Epoch 3/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.3435 - accuracy: 0.8621 - val_loss: 0.3225 - val_accuracy: 0.8655
# Epoch 4/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.2532 - accuracy: 0.9029 - val_loss: 0.6902 - val_accuracy: 0.8168
# Epoch 5/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1979 - accuracy: 0.9269 - val_loss: 0.4084 - val_accuracy: 0.8655
# Epoch 6/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1595 - accuracy: 0.9391 - val_loss: 0.8364 - val_accuracy: 0.8185
# Epoch 7/25
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.1028 - accuracy: 0.9622 - val_loss: 1.0644 - val_accuracy: 0.8185
# Epoch 8/25
# 1188/1190 [============================>.] - ETA: 0s - loss: 0.0924 - accuracy: 0.9693Restoring model weights from the end of the best epoch: 3.
# 1190/1190 [==============================] - 17s 14ms/step - loss: 0.0923 - accuracy: 0.9693 - val_loss: 0.7515 - val_accuracy: 0.8252
# Epoch 8: early stopping
# 330/330 [==============================] - 1s 2ms/step - loss: 0.5607 - accuracy: 0.7788
# Fold 9 Test Accuracy: 77.88%
# 10 Fold Accuracy: 81.69%±4.96

# %%
test_acc
# Out:
# [0.7432023882865906,
#  0.7764350175857544,
#  0.9063444137573242,
#  0.791540801525116,
#  0.7696969509124756,
#  0.8515151739120483,
#  0.8696969747543335,
#  0.8363636136054993,
#  0.8454545736312866,
#  0.7787878513336182]
