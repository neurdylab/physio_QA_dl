# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from tensorflow.keras import Input
from tensorflow.keras import Model

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.model_selection import KFold

from scipy.signal import find_peaks
from scipy.stats import mode
import numpy as np
import pickle
import matplotlib.pyplot as plt
# Out:
# 2024-01-10 09:12:25.886404: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# Load input/label to models
# RESPIRATION
# with open('resp_input.pkl', 'rb') as file:
#     x = pickle.load(file)
    
# with open('resp_label.pkl', 'rb') as file:
#     y = pickle.load(file)

# CARDIAC
with open('cardiac_input.pkl', 'rb') as file:
    x = pickle.load(file)

with open('cardiac_label.pkl', 'rb') as file:
    y = pickle.load(file)

# %%
nanmask = np.isnan(y)
print(f'#Nan Labels: {np.sum(nanmask)}\n#Remaining Samples: {np.sum(~nanmask)}')
y = y[~nanmask]
x = x[~nanmask]
# Out:
# #Nan Labels: 192
# #Remaining Samples: 3702

# %%
### GOAL is to achieve 95% classification accuracy on 10-fold CV

# Step 1: Experiment with different param. + hyperparam.: layers, kernel, stride, filter size ( see https://keras.io/api/layers/convolution_layers/convolution1d/ )
# Step 2: Experiment with different architectures

test_loss, test_acc = [], []

kernel = 5
stride = 3
kfold = KFold(n_splits=10) #, shuffle=True)
i = 0
for train, test in kfold.split(x, y):
    # Data normalization
    scaler = StandardScaler()
    X_train = scaler.fit_transform(x[train])
    X_test = scaler.transform(x[test])

    y_train = y[train]
    y_test = y[test]
    
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))


    # TO DO: Experiment with different model architectures
    model = Sequential([
        layers.Conv1D(64, kernel, stride, activation='relu', input_shape=X_train.shape[1:]),
        layers.Conv1D(32, kernel, stride, activation='relu'),
        layers.Conv1D(16, kernel, stride, activation='relu'),
        layers.Conv1D(8, kernel, stride, activation='relu'),
        layers.Flatten(),
        layers.Dense(1, activation='sigmoid')
    ])
        
    # Define the early stopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',  # Metric to monitor (e.g., validation loss)
        patience=5,           # Number of epochs with no improvement after which training will be stopped
        restore_best_weights=True,  # Restore model weights to the best achieved during training
        verbose=1  # Set to 1 to see messages about the early stopping process
    )
    
    optimizer = optimizers.Adam(learning_rate=0.001)

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    
    history = model.fit(
        X_train,
        y_train,
        epochs=25,      
        validation_split=0.2,
        batch_size=2,
        callbacks=[early_stopping]  # Add the early stopping callback
    )
    
    loss, accuracy = model.evaluate(X_test, y_test, batch_size=1)
    print(f"Fold {i} Test Accuracy: {accuracy * 100:.2f}%")
    i = i + 1
    test_loss.append(loss)
    test_acc.append(accuracy)

print("{} Fold Accuracy: {:.2f}%\u00b1{:.2f}".format(i, np.mean(test_acc)*100, np.std(test_acc)*100))
# Out:
# Epoch 1/25
# 1332/1332 [==============================] - 19s 14ms/step - loss: 0.3781 - accuracy: 0.8806 - val_loss: 0.3983 - val_accuracy: 0.8711
# Epoch 2/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.3213 - accuracy: 0.8821 - val_loss: 0.3267 - val_accuracy: 0.8876
# Epoch 3/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.1945 - accuracy: 0.9219 - val_loss: 0.4900 - val_accuracy: 0.8876
# Epoch 4/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.0839 - accuracy: 0.9718 - val_loss: 0.5930 - val_accuracy: 0.8816
# Epoch 5/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.0511 - accuracy: 0.9809 - val_loss: 0.8855 - val_accuracy: 0.8591
# Epoch 6/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.0261 - accuracy: 0.9929 - val_loss: 1.0538 - val_accuracy: 0.8861
# Epoch 7/25
# 1329/1332 [============================>.] - ETA: 0s - loss: 0.0482 - accuracy: 0.9865Restoring model weights from the end of the best epoch: 2.
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.0481 - accuracy: 0.9865 - val_loss: 0.9594 - val_accuracy: 0.8726
# Epoch 7: early stopping
# 371/371 [==============================] - 1s 2ms/step - loss: 0.3251 - accuracy: 0.9003
# Fold 0 Test Accuracy: 90.03%
# Epoch 1/25
# 1332/1332 [==============================] - 19s 14ms/step - loss: 0.3907 - accuracy: 0.8806 - val_loss: 0.3462 - val_accuracy: 0.8816
# Epoch 2/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.3287 - accuracy: 0.8930 - val_loss: 0.3005 - val_accuracy: 0.9025
# Epoch 3/25
# 1332/1332 [==============================] - 20s 15ms/step - loss: 0.2647 - accuracy: 0.9095 - val_loss: 0.2713 - val_accuracy: 0.9055
# Epoch 4/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.1538 - accuracy: 0.9452 - val_loss: 0.3405 - val_accuracy: 0.9010
# Epoch 5/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.0749 - accuracy: 0.9726 - val_loss: 0.4138 - val_accuracy: 0.9070
# Epoch 6/25
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.0425 - accuracy: 0.9857 - val_loss: 0.8053 - val_accuracy: 0.8996
# Epoch 7/25
# 1332/1332 [==============================] - 19s 14ms/step - loss: 0.0295 - accuracy: 0.9906 - val_loss: 0.6503 - val_accuracy: 0.9100
# Epoch 8/25
# 1331/1332 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 0.9921Restoring model weights from the end of the best epoch: 3.
# 1332/1332 [==============================] - 18s 14ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 0.5580 - val_accuracy: 0.9205
# Epoch 8: early stopping
# 371/371 [==============================] - 1s 2ms/step - loss: 0.4074 - accuracy: 0.8733
# Fold 1 Test Accuracy: 87.33%
# Epoch 1/25
# 1333/1333 [==============================] - 20s 14ms/step - loss: 0.3770 - accuracy: 0.8841 - val_loss: 0.3757 - val_accuracy: 0.8711
# Epoch 2/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3240 - accuracy: 0.8844 - val_loss: 0.3453 - val_accuracy: 0.8711
# Epoch 3/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.2152 - accuracy: 0.9054 - val_loss: 0.4839 - val_accuracy: 0.8561
# Epoch 4/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0848 - accuracy: 0.9666 - val_loss: 0.5458 - val_accuracy: 0.8696
# Epoch 5/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0426 - accuracy: 0.9794 - val_loss: 1.1895 - val_accuracy: 0.8966
# Epoch 6/25
# 1333/1333 [==============================] - 19s 15ms/step - loss: 0.0377 - accuracy: 0.9887 - val_loss: 1.3599 - val_accuracy: 0.8906
# Epoch 7/25
# 1332/1333 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9872Restoring model weights from the end of the best epoch: 2.
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0414 - accuracy: 0.9872 - val_loss: 1.0360 - val_accuracy: 0.8516
# Epoch 7: early stopping
# 370/370 [==============================] - 1s 2ms/step - loss: 0.3874 - accuracy: 0.8757
# Fold 2 Test Accuracy: 87.57%
# Epoch 1/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3698 - accuracy: 0.8852 - val_loss: 0.3436 - val_accuracy: 0.8711
# Epoch 2/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3225 - accuracy: 0.8852 - val_loss: 0.3388 - val_accuracy: 0.8711
# Epoch 3/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.2063 - accuracy: 0.9156 - val_loss: 0.4202 - val_accuracy: 0.8711
# Epoch 4/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0930 - accuracy: 0.9595 - val_loss: 0.5846 - val_accuracy: 0.8381
# Epoch 5/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0387 - accuracy: 0.9865 - val_loss: 1.4592 - val_accuracy: 0.8636
# Epoch 6/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0455 - accuracy: 0.9854 - val_loss: 1.2650 - val_accuracy: 0.8846
# Epoch 7/25
# 1330/1333 [============================>.] - ETA: 0s - loss: 0.0468 - accuracy: 0.9835Restoring model weights from the end of the best epoch: 2.
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0467 - accuracy: 0.9835 - val_loss: 1.4413 - val_accuracy: 0.8246
# Epoch 7: early stopping
# 370/370 [==============================] - 1s 2ms/step - loss: 0.4006 - accuracy: 0.8676
# Fold 3 Test Accuracy: 86.76%
# Epoch 1/25
# 1333/1333 [==============================] - 20s 14ms/step - loss: 0.3597 - accuracy: 0.8938 - val_loss: 0.4042 - val_accuracy: 0.8711
# Epoch 2/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3306 - accuracy: 0.8946 - val_loss: 0.4300 - val_accuracy: 0.8711
# Epoch 3/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.2709 - accuracy: 0.9069 - val_loss: 0.3393 - val_accuracy: 0.8921
# Epoch 4/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.1548 - accuracy: 0.9392 - val_loss: 0.4219 - val_accuracy: 0.8936
# Epoch 5/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0682 - accuracy: 0.9760 - val_loss: 0.7568 - val_accuracy: 0.8966
# Epoch 6/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0311 - accuracy: 0.9906 - val_loss: 0.9523 - val_accuracy: 0.8756
# Epoch 7/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0264 - accuracy: 0.9914 - val_loss: 1.3624 - val_accuracy: 0.8906
# Epoch 8/25
# 1331/1333 [============================>.] - ETA: 0s - loss: 0.0291 - accuracy: 0.9921Restoring model weights from the end of the best epoch: 3.
# 1333/1333 [==============================] - 19s 15ms/step - loss: 0.0291 - accuracy: 0.9921 - val_loss: 1.1112 - val_accuracy: 0.8651
# Epoch 8: early stopping
# 370/370 [==============================] - 1s 2ms/step - loss: 0.5252 - accuracy: 0.8135
# Fold 4 Test Accuracy: 81.35%
# Epoch 1/25
# 1333/1333 [==============================] - 20s 14ms/step - loss: 0.3859 - accuracy: 0.8859 - val_loss: 0.3635 - val_accuracy: 0.8711
# Epoch 2/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3278 - accuracy: 0.8908 - val_loss: 0.3076 - val_accuracy: 0.9055
# Epoch 3/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.2177 - accuracy: 0.9227 - val_loss: 0.3454 - val_accuracy: 0.8906
# Epoch 4/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0892 - accuracy: 0.9636 - val_loss: 0.6073 - val_accuracy: 0.9070
# Epoch 5/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0648 - accuracy: 0.9782 - val_loss: 0.8764 - val_accuracy: 0.8711
# Epoch 6/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0432 - accuracy: 0.9824 - val_loss: 0.8879 - val_accuracy: 0.8861
# Epoch 7/25
# 1329/1333 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 0.9913Restoring model weights from the end of the best epoch: 2.
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0246 - accuracy: 0.9914 - val_loss: 0.9664 - val_accuracy: 0.8786
# Epoch 7: early stopping
# 370/370 [==============================] - 1s 2ms/step - loss: 0.3852 - accuracy: 0.8703
# Fold 5 Test Accuracy: 87.03%
# Epoch 1/25
# 1333/1333 [==============================] - 20s 14ms/step - loss: 0.3914 - accuracy: 0.8803 - val_loss: 0.3656 - val_accuracy: 0.8711
# Epoch 2/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3417 - accuracy: 0.8807 - val_loss: 0.3010 - val_accuracy: 0.8726
# Epoch 3/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.2426 - accuracy: 0.9062 - val_loss: 0.3935 - val_accuracy: 0.8711
# Epoch 4/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.1235 - accuracy: 0.9490 - val_loss: 0.3205 - val_accuracy: 0.8786
# Epoch 5/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0554 - accuracy: 0.9782 - val_loss: 0.7054 - val_accuracy: 0.8756
# Epoch 6/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0591 - accuracy: 0.9794 - val_loss: 0.5050 - val_accuracy: 0.8861
# Epoch 7/25
# 1330/1333 [============================>.] - ETA: 0s - loss: 0.0372 - accuracy: 0.9842Restoring model weights from the end of the best epoch: 2.
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0372 - accuracy: 0.9842 - val_loss: 0.6706 - val_accuracy: 0.8756
# Epoch 7: early stopping
# 370/370 [==============================] - 1s 2ms/step - loss: 0.2838 - accuracy: 0.8973
# Fold 6 Test Accuracy: 89.73%
# Epoch 1/25
# 1333/1333 [==============================] - 20s 14ms/step - loss: 0.4104 - accuracy: 0.8735 - val_loss: 0.3590 - val_accuracy: 0.8711
# Epoch 2/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3473 - accuracy: 0.8750 - val_loss: 0.3239 - val_accuracy: 0.8711
# Epoch 3/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.2634 - accuracy: 0.8931 - val_loss: 0.4527 - val_accuracy: 0.8726
# Epoch 4/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.1217 - accuracy: 0.9516 - val_loss: 0.5731 - val_accuracy: 0.8936
# Epoch 5/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0445 - accuracy: 0.9842 - val_loss: 0.8094 - val_accuracy: 0.9010
# Epoch 6/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0522 - accuracy: 0.9846 - val_loss: 1.0463 - val_accuracy: 0.8906
# Epoch 7/25
# 1330/1333 [============================>.] - ETA: 0s - loss: 0.0239 - accuracy: 0.9925Restoring model weights from the end of the best epoch: 2.
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 1.2295 - val_accuracy: 0.8906
# Epoch 7: early stopping
# 370/370 [==============================] - 1s 2ms/step - loss: 0.1732 - accuracy: 0.9514
# Fold 7 Test Accuracy: 95.14%
# Epoch 1/25
# 1333/1333 [==============================] - 21s 15ms/step - loss: 0.4052 - accuracy: 0.8724 - val_loss: 0.3729 - val_accuracy: 0.9055
# Epoch 2/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3579 - accuracy: 0.8762 - val_loss: 0.3084 - val_accuracy: 0.9385
# Epoch 3/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.2738 - accuracy: 0.9021 - val_loss: 0.2582 - val_accuracy: 0.9295
# Epoch 4/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.1334 - accuracy: 0.9527 - val_loss: 0.2589 - val_accuracy: 0.9460
# Epoch 5/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0564 - accuracy: 0.9805 - val_loss: 0.5475 - val_accuracy: 0.8861
# Epoch 6/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0365 - accuracy: 0.9861 - val_loss: 0.4828 - val_accuracy: 0.9220
# Epoch 7/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0372 - accuracy: 0.9891 - val_loss: 0.7238 - val_accuracy: 0.9265
# Epoch 8/25
# 1330/1333 [============================>.] - ETA: 0s - loss: 0.0194 - accuracy: 0.9947Restoring model weights from the end of the best epoch: 3.
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.8312 - val_accuracy: 0.9220
# Epoch 8: early stopping
# 370/370 [==============================] - 1s 2ms/step - loss: 0.3271 - accuracy: 0.9027
# Fold 8 Test Accuracy: 90.27%
# Epoch 1/25
# 1333/1333 [==============================] - 20s 14ms/step - loss: 0.3937 - accuracy: 0.8728 - val_loss: 0.3189 - val_accuracy: 0.9160
# Epoch 2/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.3547 - accuracy: 0.8739 - val_loss: 0.2457 - val_accuracy: 0.9160
# Epoch 3/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.2591 - accuracy: 0.8994 - val_loss: 0.1713 - val_accuracy: 0.9430
# Epoch 4/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.1468 - accuracy: 0.9452 - val_loss: 0.1357 - val_accuracy: 0.9550
# Epoch 5/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0819 - accuracy: 0.9707 - val_loss: 0.1637 - val_accuracy: 0.9550
# Epoch 6/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0432 - accuracy: 0.9846 - val_loss: 0.3343 - val_accuracy: 0.9010
# Epoch 7/25
# 1333/1333 [==============================] - 19s 14ms/step - loss: 0.0389 - accuracy: 0.9902 - val_loss: 0.2117 - val_accuracy: 0.9445
# Epoch 8/25
# 1333/1333 [==============================] - 62s 47ms/step - loss: 0.0268 - accuracy: 0.9921 - val_loss: 0.3168 - val_accuracy: 0.9445
# Epoch 9/25
# 1331/1333 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9902Restoring model weights from the end of the best epoch: 4.
# 1333/1333 [==============================] - 20s 15ms/step - loss: 0.0277 - accuracy: 0.9902 - val_loss: 0.3158 - val_accuracy: 0.9355
# Epoch 9: early stopping
# 370/370 [==============================] - 1s 3ms/step - loss: 0.1902 - accuracy: 0.9405
# Fold 9 Test Accuracy: 94.05%
# 10 Fold Accuracy: 88.93%±3.72

# %%
test_acc
# Out:
# [0.9002695679664612,
#  0.8733153343200684,
#  0.8756756782531738,
#  0.8675675392150879,
#  0.8135135173797607,
#  0.8702702522277832,
#  0.8972973227500916,
#  0.9513513445854187,
#  0.9027026891708374,
#  0.9405405521392822]
